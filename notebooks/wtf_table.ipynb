# %%
import pandas as pd

# %%
ws_file = '/Users/mwilde/Dropbox/CGM2/Galaxies/SQuADenhancedgalaxies.csv'

# %%
df = pd.read_csv(ws_file)

# %%
df.loc[~pd.isna(df.cgm_name_x)]
# Out:
#      Unnamed: 0 Unnamed: 0.1                specfile_x  \
# 0             0          Joe  J022601.51+001532.5.fits
# 1             1          Joe  J022602.41+001536.6.fits
# 2             2          Joe  J022606.98+001451.4.fits
# 3             3          Joe  J022607.08+001612.7.fits
# 4             4          Joe  J022608.02+001427.2.fits
# 5             5          Joe  J022609.11+001513.1.fits
# 6             6          Joe  J022610.26+001603.7.fits
# 7             7          Joe  J022610.44+001514.0.fits
# 8             8          Joe  J022611.06+001323.6.fits
# 9             9          Joe  J022611.40+001341.3.fits
# 10           10          Joe  J022612.15+001357.5.fits
# 11           11          Joe  J022612.18+001407.3.fits
# 12           12          Joe  J022612.18+001506.0.fits
# 13           13          Joe  J022613.33+001358.7.fits
# 14           14          Joe  J022614.39+001620.4.fits
# 15           15          Joe  J022614.58+001351.4.fits
# ...

# %%
df['cgm_name_y'].loc[~pd.isna(df.cgm_name_y)]
# Out:
# 0      b'J0226+0015_271_194'
# 1      b'J0226+0015_272_181'
# 2      b'J0226+0015_251_119'
# 3      b'J0226+0015_291_119'
# 4      b'J0226+0015_237_115'
# 5       b'J0226+0015_258_82'
# 6       b'J0226+0015_298_72'
# 7       b'J0226+0015_255_62'
# 8      b'J0226+0015_202_136'
# 9      b'J0226+0015_203_118'
# 10      b'J0226+0015_201_99'
# 11      b'J0226+0015_203_89'
# 12      b'J0226+0015_235_42'
# 13      b'J0226+0015_191_93'
# 14      b'J0226+0015_359_51'
# 15      b'J0226+0015_179_98'
# 16       b'J0226+0015_33_65'
# 17      b'J0226+0015_14_190'
# 18      b'J0226+0015_129_68'
# 19      b'J0226+0015_123_99'
# 20      b'J0226+0015_57_134'
# 21     b'J0809+4619_239_190'
# 22     b'J0809+4619_313_120'
# 23     b'J0809+4619_334_165'
# 24      b'J0809+4619_313_94'
# 25      b'J0809+4619_252_71'
# 26      b'J0809+4619_308_55'
# 27      b'J0809+4619_302_51'
# 28      b'J0809+4619_252_45'
# 29      b'J0809+4619_232_50'
#                ...
# 947      b'J1555+3628_61_71'
# ...

# %%
df.cgm_name_x.unique().shape
# Out:
# (750,)

# %%
df.cgm_name_x.shape
# Out:
# (977,)
